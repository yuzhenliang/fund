# %%
import xalpha as xa
import pandas as pd
xa.set_display('notebook')

path='fund_bill/summary.csv'
read=xa.record(path)

# %%
sysopen = xa.mul(status=read.status)

# %%
sysopen.combsummary().sort_values(by='基金代码',ascending=True)
# Out:
#                基金名称    基金代码    当日净值    单位成本     持有份额      基金现值     基金总申购  \
# 0          易方达中小盘混合  110011  9.6853  6.3318  2851.16  27614.34  22414.83
# 1         华安创业板50指数  160420  1.5922  0.0000     0.00      0.00   4600.00
# 2  富国天惠成长混合A/B(LOF)  161005  3.8126  3.4935  1746.11   6657.22   6100.00
# 3                总计   total     NaN     NaN      NaN  34271.56  33114.83
#
#      历史最大占用    基金持有成本  基金分红与赎回       换手率    基金收益总额    投资收益率
# 0  18052.93  18052.93   4361.9  0.655424   9561.41  52.9632
# 1   4600.00   -764.80   5364.8  0.432541    764.80  16.6261
# 2   6100.00   6100.00      0.0  0.899015    557.22   9.1348
# 3  23388.13  23388.13   9726.7  0.365752  10883.43  46.5340

# %%
sysopen.xirrrate()
# Out:
# 0.7458134923313525

# %%
sysopen.v_positions('2021-02-01') # 可视化指定日期的仓位分布
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fae3711f5f32463095846f64e2b2fb42" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fae3711f5f32463095846f64e2b2fb42 = echarts.init(
#                     document.getElementById('fae3711f5f32463095846f64e2b2fb42'), 'white', {renderer: 'canvas'});
#                 var option_fae3711f5f32463095846f64e2b2fb42 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
sysopen.v_tradevolume()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="159629c773b84ca48e24a7f7e0d4ee73" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_159629c773b84ca48e24a7f7e0d4ee73 = echarts.init(
#                     document.getElementById('159629c773b84ca48e24a7f7e0d4ee73'), 'white', {renderer: 'canvas'});
#                 var option_159629c773b84ca48e24a7f7e0d4ee73 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
sysopen.v_positions_history(rendered=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c1a0ee65db49452ab9ef423047df499a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c1a0ee65db49452ab9ef423047df499a = echarts.init(
#                     document.getElementById('c1a0ee65db49452ab9ef423047df499a'), 'white', {renderer: 'canvas'});
#                 var option_c1a0ee65db49452ab9ef423047df499a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
sysopen.totcftable
# Out:
#          date   cash
# 0  2018-08-02 -200.0
# 1  2018-08-09 -200.0
# 2  2018-08-16 -200.0
# 3  2018-08-23 -200.0
# 4  2018-08-30 -200.0
# ..        ...    ...
# 84 2021-01-04 -800.0
# 85 2021-01-11 -800.0
# 86 2021-01-18 -800.0
# 87 2021-01-25 -550.0
# 88 2021-02-01 -500.0
#
# [89 rows x 2 columns]
